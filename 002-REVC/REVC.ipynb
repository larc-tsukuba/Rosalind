# %% [markdown]
# 課題3 相補的な塩基への置き換え
# インプットの塩基配列に対して、A-T, C-Gを入れ替えた相補的配列を出力する
# 3'-5' となるように出力する必要があると指定されているため、入れ替えた後並びを反転する必要がある

# %%
seq="..."

complement_seq = ""

# %% [markdown]
# translate メソッドで入れ替えて
# 逆順に並べ替える

# %%
complement_seq = seq.translate(str.maketrans('ATCG','TAGC'))
complement_seq = complement_seq[::-1]
print(complement_seq)
# Out:
# ...

# %% [markdown]
# 相補的に対応する辞書を作る
# inputの末尾から塩基ごとに変換を繰り返してcomplement_seqの末尾に付加する

# %%
complement_map = {'A':'T','T':'A','C':'G','G':'C'}
for base in seq[::-1]:
    complement_seq += complement_map[base]

print(complement_seq)
# Out:
# ...
