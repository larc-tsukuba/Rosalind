# %% [markdown]
# 課題2 DNA配列をRNA配列に変換する
#
# 塩基配列におけるDNAとRNAの違いは、ＴがＵに置き換わっていること、構成する糖鎖がデオキシリボース, リボースである
# この課題では塩基配列中のTをUに変換する。

# %%
#塩基配列のインプット
seq = '...'

# %%
#replaceメソッドを使って、TをUに置き換える
seq = seq.replace('T', 'U')
print(seq)
# Out:
# ...

# %%
print(seq.count('T'))
print(seq.count('U'))
# Out:
# 0
# 232
