# %% [markdown]
# # 036-KMP Speed up motif finding
#
# ## Shortening the motif search
# - 標準的な、ある一つの配列がもう一つの部分配列となるような部分を探す方法は、長い配列を一つ一つスライドしながら精査するというもの
# - 100塩基目にミスマッチがあったとき、99塩基戻ってまた比較を始めなければならないが、これは非効率である
# - 計算量は O(len(S)*len(T)) くらいになる？
#
# ## 具体例
# - t = ACGTACGT, s = TAGGTACGTACGGCATCACG
# - s[5:12] には 7個のマッチがある
# - しかし、s[12] = G t[7] = T でミスマッチになる
# - 次に s[6] に戻って再び走査することを考えるが、戻る必要はない。
# - なぜなら、s[6:9] はすでに A ではないことがわかっているからである
# - では、s[9]から走査した場合はというと、t[0:4] = t[4:8] = ACGT なので、すでに s[12] ≠ t[7] がわかっているので、これも t[3] でミスマッチになるとわかる
# - したがって、s[9] もスライド走査の候補ではなく、次はs[14] から始めるべきである
# - このようなアルゴリズムは Knuth-Morris-Pratt algorithm (KMP) として知られている
# - [KMPのわかりやすい説明](https://qiita.com/t_fuki/items/f32406da0233ed51ec86)
#
# ## 課題
# - 長さn の文字列 s があるとする
# -  この時の Failure array P を求めよ。
#
# - 文字列 s の prefix と suffix は以下のように定義される
# - prefix = s[1:j]
# - suffix = s[k:n]
# - (簡単のために1-index, 開区間で考える)
#
# - Failure array P[k] = 部分文字列 s[j:k] が ある prefix [1:k-j+1] に等しいような最長の長さ
# - ただし j ≠ 1
# - j = 1 ならば、s[j:k] = s[1:k] となり、常に prefix [1:k] と等しくなり、すべてのkに対して p[k] = k　が成り立ってしまうから
# - この言い方は非常に分かりにくい！
# - しかし、言っていることは、KMP algolithm でいう部分マッチテーブルと同一である。
# - 言い換えると、s[1:k] の部分配列を考えたとき、prefix は s[1:j], 同じ長さのsuffix は s[k-l+1:n]となる
# - つまり、1からk までの部分配列の中で、ある長さのprefixと、それと同じ長さのsuffix が一致する最大の長さが P[k]
# - P[1] = 0 と定義する
#
# ## 要約
# - つまり、何が言いたいかというと、
# - 長さn の文字列 s の部分マッチテーブルを計算せよということ
